# %%
import pandas as pd
import numpy as np
from sklearn.neural_network import MLPRegressor
import pickle as pkl

# %%
def hot1Encode(S):
    encoded = []
    dct_bases = {'A': [1, 0, 0, 0], 'T': [0, 1, 0, 0], 'G': [0, 0, 1, 0], 'C': [0, 0, 0, 1]}
    for b in S:
        encoded.extend(dct_bases[b])
    return encoded

# %%
dataset_file = '/home/jardic/Documents/projects/jk/datasets/datasets_prepped/strc_km.csv'
fractions = [0.001, 0.003, 0.01, 0.03, 0.1, 0.3]

# %%
df = pd.read_csv(dataset_file, usecols=['varseq', 'cpm'])

for sampled_fraction in fractions:

    # Create a random split of defined size
    index = df.index.tolist()
    trn_idxs = np.random.choice(index, size=int(len(df) * sampled_fraction))
    index = list(set(index) - set(trn_idxs))
    tst_idxs = np.random.choice(index, size=int(len(df) * sampled_fraction))
    
    # Save the train and test indexes
    splits = {'trn':trn_idxs, 'tst':tst_idxs}
    
    # Use this to load splits, for reproducibility
    with open('splits_' + str(sampled_fraction).replace('.', '_') + '.pkl', mode='wb') as sf:
        pkl.dump(splits, sf)
    
    # Use splits indexes to make X_trn, y_trn, X_tst, y_tst
    df_trn = df.loc[splits['trn']]
    df_tst = df.loc[splits['tst']]
    
    X_trn = np.array([hot1Encode(s) for s in df_trn['varseq']])
    y_trn = df_trn['cpm']
    X_tst = np.array([hot1Encode(s) for s in df_tst['varseq']])
    y_tst = df_tst['cpm']
    
    # Train a simple MLP on the random split
    
    model = MLPRegressor(random_state=1,
             hidden_layer_sizes=(100, 100, 100, 100),
             activation='relu',
             batch_size=100,
             learning_rate_init=0.0001,
             early_stopping=True,
             validation_fraction=0.1,
            max_iter=40,
            learning_rate='constant',
            verbose=True)
    
    model.fit(X_trn, y_trn)
    
    predictions = model.predict(X_tst)

    with open('observed_and_predicted_' + str(sampled_fraction).replace('.', '_') + '.pkl', mode='wb') as rf:
        splits = pkl.dump([y_tst, predictions], rf)
# Out:
# Iteration 1, loss = 0.49570653
# Validation score: 0.003485
# Iteration 2, loss = 0.48435429
# Validation score: 0.008464
# Iteration 3, loss = 0.48006321
# Validation score: 0.011853
# Iteration 4, loss = 0.47566463
# Validation score: 0.015684
# Iteration 5, loss = 0.47104573
# Validation score: 0.023304
# Iteration 6, loss = 0.46671326
# Validation score: 0.028094
# Iteration 7, loss = 0.46178371
# Validation score: 0.035437
# Iteration 8, loss = 0.45550774
# Validation score: 0.043795
# Iteration 9, loss = 0.44684744
# Validation score: 0.057007
# Iteration 10, loss = 0.43724324
# Validation score: 0.069693
# Iteration 11, loss = 0.42703060
# Validation score: 0.086755
# Iteration 12, loss = 0.41473367
# Validation score: 0.100367
# Iteration 13, loss = 0.40067357
# Validation score: 0.115057
# Iteration 14, loss = 0.38964843
# Validation score: 0.123076
# Iteration 15, loss = 0.37474503
# Validation score: 0.147261
# Iteration 16, loss = 0.35846840
# Validation score: 0.168709
# Iteration 17, loss = 0.34583542
# Validation score: 0.164895
# Iteration 18, loss = 0.32876670
# Validation score: 0.161853
# Iteration 19, loss = 0.31592200
# Validation score: 0.549128
# Iteration 9, loss = 0.23535300
# Validation score: 0.549213
# Iteration 10, loss = 0.19987949
# Validation score: 0.637483
# Iteration 11, loss = 0.19040272
# Validation score: 0.682706
# Iteration 12, loss = 0.16490529
# Validation score: 0.721337
# Iteration 13, loss = 0.15339776
# Validation score: 0.767404
# Iteration 14, loss = 0.13356964
# Validation score: 0.800588
# Iteration 15, loss = 0.12281166
# Validation score: 0.811139
# Iteration 16, loss = 0.11561849
# Validation score: 0.732125
# Iteration 17, loss = 0.10560310
# Validation score: 0.869184
# Iteration 18, loss = 0.09172776
# Validation score: 0.877749
# Iteration 19, loss = 0.09236592
# Validation score: 0.854335
# Iteration 20, loss = 0.08497693
# Validation score: 0.913873
# Iteration 21, loss = 0.07674364
# Validation score: 0.924593
# Iteration 22, loss = 0.08564370
# Validation score: 0.921233
# Iteration 23, loss = 0.06918412
# Validation score: 0.924735
# Iteration 24, loss = 0.06622557
# Validation score: 0.916516
# Iteration 25, loss = 0.06759942
# Validation score: 0.868149
# Iteration 26, loss = 0.07216108
# Validation score: 0.924029
# Iteration 27, loss = 0.05656445
# Validation score: 0.944708
# Iteration 28, loss = 0.06619951
# Validation score: 0.936271
# Iteration 29, loss = 0.06007833
# Validation score: 0.943210
# Iteration 30, loss = 0.05511249
# Validation score: 0.941099
# Iteration 31, loss = 0.05006367
# Validation score: 0.945258
# Iteration 32, loss = 0.04725476
# Validation score: 0.945176
# Iteration 33, loss = 0.05052740
# Validation score: 0.915504
# Iteration 34, loss = 0.04491124
# Validation score: 0.925225
# Iteration 35, loss = 0.05071602
# Validation score: 0.940751
# Iteration 36, loss = 0.03755342
# Validation score: 0.940860
# Iteration 37, loss = 0.03790249
# Validation score: 0.932681
# Iteration 38, loss = 0.04499616
# Validation score: 0.940245
# Iteration 39, loss = 0.03451174
# Validation score: 0.944205
# Iteration 40, loss = 0.04292206
# Validation score: 0.943116
# /home/jardic/miniconda3/envs/ae_ml/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (40) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.70161836
# Validation score: 0.282722
# Iteration 2, loss = 0.53369057
# Validation score: 0.459235
# Iteration 3, loss = 0.43219214
# Validation score: 0.573674
# Iteration 4, loss = 0.37531558
# Validation score: 0.655672
# Iteration 5, loss = 0.32394043
# Validation score: 0.195845
# Iteration 6, loss = 0.28079553
# Validation score: 0.706330
# Iteration 7, loss = 0.23878943
# Validation score: 0.783459
# Iteration 8, loss = 0.22151180
# Validation score: 0.791190
# Iteration 9, loss = 0.18448114
# Validation score: 0.702182
# Iteration 10, loss = 0.17858753
# Validation score: 0.815262
# Iteration 11, loss = 0.15433560
# Validation score: 0.829771
# Iteration 12, loss = 0.15433215
# Validation score: 0.864607
# Iteration 13, loss = 0.13074988
# Validation score: 0.834412
# Iteration 14, loss = 0.13286680
# Validation score: 0.801182
# Iteration 15, loss = 0.11344646
# Validation score: 0.849172
# Iteration 16, loss = 0.11069027
# Validation score: 0.847407
# Iteration 17, loss = 0.09717716
# Validation score: 0.854562
# Iteration 18, loss = 0.11330697
# Validation score: 0.892732
# Iteration 19, loss = 0.09309010
# Validation score: 0.869249
# Iteration 20, loss = 0.08570156
# Validation score: 0.789343
# Iteration 21, loss = 0.09534686
# Validation score: 0.878019
# Iteration 22, loss = 0.08072611
# Validation score: 0.882873
# Iteration 23, loss = 0.07310321
# Validation score: 0.788026
# Iteration 24, loss = 0.08563434
# Validation score: 0.882824
# Iteration 25, loss = 0.07678662
# Validation score: 0.839335
# Iteration 26, loss = 0.07505961
# Validation score: 0.869873
# Iteration 27, loss = 0.06698935
# Validation score: 0.875109
# Iteration 28, loss = 0.06692232
# Validation score: 0.882375
# Iteration 29, loss = 0.06042501
# Validation score: 0.848527
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.59365985
# Validation score: 0.458388
# Iteration 2, loss = 0.37266926
# Validation score: 0.656117
# Iteration 3, loss = 0.26870128
# Validation score: 0.675634
# Iteration 4, loss = 0.20554728
# Validation score: 0.820353
# Iteration 5, loss = 0.16733883
# Validation score: 0.693975
# Iteration 6, loss = 0.14817093
# Validation score: 0.724490
# Iteration 7, loss = 0.13317206
# Validation score: 0.870059
# Iteration 8, loss = 0.11772873
# Validation score: 0.849697
# Iteration 9, loss = 0.11305869
# Validation score: 0.804017
# Iteration 10, loss = 0.10722769
# Validation score: 0.851573
# Iteration 11, loss = 0.10464189
# Validation score: 0.882281
# Iteration 12, loss = 0.09247423
# Validation score: 0.826817
# Iteration 13, loss = 0.08735116
# Validation score: 0.908130
# Iteration 14, loss = 0.07903493
# Validation score: 0.861574
# Iteration 15, loss = 0.08122301
# Validation score: 0.882141
# Iteration 16, loss = 0.07522920
# Validation score: 0.840558
# Iteration 17, loss = 0.06962166
# Validation score: 0.899612
# Iteration 18, loss = 0.07278804
# Validation score: 0.895306
# Iteration 19, loss = 0.06808301
# Validation score: 0.874376
# Iteration 20, loss = 0.06818301
# Validation score: 0.921757
# Iteration 21, loss = 0.06264217
# Validation score: 0.900548
# Iteration 22, loss = 0.05800336
# Validation score: 0.904890
# Iteration 23, loss = 0.06131117
# Validation score: 0.890191
# Iteration 24, loss = 0.05330715
# Validation score: 0.900452
# Iteration 25, loss = 0.05659949
# Validation score: 0.893930
# Iteration 26, loss = 0.05153048
# Validation score: 0.885413
# Iteration 27, loss = 0.05045097
# Validation score: 0.927951
# Iteration 28, loss = 0.04618609
# Validation score: 0.911187
# Iteration 29, loss = 0.04334087
# Validation score: 0.915665
# Iteration 30, loss = 0.04936863
# Validation score: 0.939523
# Iteration 31, loss = 0.04449790
# Validation score: 0.877904
# Iteration 32, loss = 0.04029885
# Validation score: 0.913167
# Iteration 33, loss = 0.04509911
# Validation score: 0.912368
# Iteration 34, loss = 0.04516861
# Validation score: 0.936085
# Iteration 35, loss = 0.04084951
# Validation score: 0.920829
# Iteration 36, loss = 0.04242954
# Validation score: 0.911280
# Iteration 37, loss = 0.03847668
# Validation score: 0.915487
# Iteration 38, loss = 0.04173726
# Validation score: 0.902005
# Iteration 39, loss = 0.03759970
# Validation score: 0.940391
# Iteration 40, loss = 0.03890333
# Validation score: 0.892983
# /home/jardic/miniconda3/envs/ae_ml/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (40) reached and the optimization hasn't converged yet.
#   warnings.warn(
